# %% [markdown]
# #Mining the Social Web, 2nd Edition
#
# ##Chapter 1: Mining Twitter: Exploring Trending Topics, Discovering What People Are Talking About, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# In the somewhat unlikely event that you've somehow stumbled across this notebook outside of its context on GitHub, [you can find the full source code repository here](http://bit.ly/16kGNyb).
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application. There are four primary identifiers you'll need to note for an OAuth 1.0A workflow: consumer key, consumer secret, access token, and access token secret. Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.
#
# <img src="files/resources/ch01-twitter/images/Twitter-AppCredentials.png" width="600px">

# %% [markdown]
# If you are taking advantage of the virtual machine experience for this chapter that is powered by Vagrant, you should just be able to execute the code in this notebook without any worries whatsoever about installing dependencies. If you are running the code from your own development envioronment, however, be advised that these examples in this chapter take advantage of a Python package called [twitter](https://github.com/sixohsix/twitter) to make API calls. You can install this package in a terminal with [pip](https://pypi.python.org/pypi/pip) with the command `pip install twitter`, preferably from within a [Python virtual environment](https://pypi.python.org/pypi/virtualenv).

# %% [markdown]
# Once installed, you should be able to open up a Python interpreter (or better yet, your [IPython](http://ipython.org/) interpreter) and get rolling.

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter
import json

# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation.

CONSUMER_KEY = 'iLyBQ9kRzr0trAGDmVPYCMqvG'
CONSUMER_SECRET ='FcFBpuW6nBBxQ9sTgOXAX6D7qx7ef3SZWKrrAuDFgOQwH1W4dH'
OAUTH_TOKEN = '717647756-3JjORc7QDsKEZAFTI913RMWQsUbYeq6aCWx8Qc6B'
OAUTH_TOKEN_SECRET = 'OcqMoeZYLhq8L3x9LD69CoMco8Iv5ZC3ITkvYBJCqe4Cs'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print twitter_api
# Out:
# <twitter.api.Twitter object at 0x2621150>

# %% [markdown]
# ## Example 2. Retrieving trends & showing API responses as pretty JSON

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977
NGR_WOE_ID = 23424908
UK_WOE_ID = 23424975

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

uk_trends = twitter_api.trends.place(_id=UK_WOE_ID, _exclude='hashtags')
nigeria_trends = twitter_api.trends.place(_id=NGR_WOE_ID, _exclude='hashtags')
united_states_trends = twitter_api.trends.place(_id=US_WOE_ID, _exclude='hashtags')


print json.dumps(nigeria_trends, indent=1)
print
print json.dumps(united_states_trends, indent=1)
print
print json.dumps(uk_trends, indent=1)
print
# Out:
# [
#  {
#   "created_at": "2015-05-31T17:44:07Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23JJCAFROBEATSLIVE",
#     "query": "%23JJCAFROBEATSLIVE",
#     "name": "#JJCAFROBEATSLIVE",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SundayChilloutZone",
#     "query": "%23SundayChilloutZone",
#     "name": "#SundayChilloutZone",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23FlamzNATION_1EOY",
#     "query": "%23FlamzNATION_1EOY",
#     "name": "#FlamzNATION_1EOY",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SundayGroove",
#     "query": "%23SundayGroove",
#     "name": "#SundayGroove",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MOTYconcertTonight",
#     "query": "%23MOTYconcertTonight",
#     "name": "#MOTYconcertTonight",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Tottenham",
#     "query": "Tottenham",
#     "name": "Tottenham",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Jack+Wilshere%22",
#     "query": "%22Jack+Wilshere%22",
#     "name": "Jack Wilshere",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Arsenal",
#     "query": "Arsenal",
#     "name": "Arsenal",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Messi",
#     "query": "Messi",
#     "name": "Messi",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Sanchez",
#     "query": "Sanchez",
#     "name": "Sanchez",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2015-05-31T17:45:53Z",
#   "locations": [
#    {
#     "woeid": 23424908,
#     "name": "Nigeria"
#    }
#   ]
#  }
# ]
#
# [
#  {
#   "created_at": "2015-05-31T17:44:03Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%22The+1975%22",
#     "query": "%22The+1975%22",
#     "name": "The 1975",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ConnorFrantaTwitterMeetUp",
#     "query": "%23ConnorFrantaTwitterMeetUp",
#     "name": "#ConnorFrantaTwitterMeetUp",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SundayFunday",
#     "query": "%23SundayFunday",
#     "name": "#SundayFunday",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23InsteadOfGoingToChurchIm",
#     "query": "%23InsteadOfGoingToChurchIm",
#     "name": "#InsteadOfGoingToChurchIm",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ZaynMalikInManila",
#     "query": "%23ZaynMalikInManila",
#     "name": "#ZaynMalikInManila",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23FakeApocalypseFacts",
#     "query": "%23FakeApocalypseFacts",
#     "name": "#FakeApocalypseFacts",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Berdych",
#     "query": "Berdych",
#     "name": "Berdych",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22John+Kerry%22",
#     "query": "%22John+Kerry%22",
#     "name": "John Kerry",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Brian+Williams%22",
#     "query": "%22Brian+Williams%22",
#     "name": "Brian Williams",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Clint+Eastwood%22",
#     "query": "%22Clint+Eastwood%22",
#     "name": "Clint Eastwood",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2015-05-31T17:45:54Z",
#   "locations": [
#    {
#     "woeid": 23424977,
#     "name": "United States"
#    }
#   ]
#  }
# ]
#
# [
#  {
#   "created_at": "2015-05-31T17:38:54Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=Rangers",
#     "query": "Rangers",
#     "name": "Rangers",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22The+1975%22",
#     "query": "%22The+1975%22",
#     "name": "The 1975",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23AskFifthHarmony",
#     "query": "%23AskFifthHarmony",
#     "name": "#AskFifthHarmony",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Motherwell",
#     "query": "Motherwell",
#     "name": "Motherwell",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ConnorFrantaTwitterMeetUp",
#     "query": "%23ConnorFrantaTwitterMeetUp",
#     "name": "#ConnorFrantaTwitterMeetUp",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23askthescript",
#     "query": "%23askthescript",
#     "name": "#askthescript",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23AddSoccerRuinAMovie",
#     "query": "%23AddSoccerRuinAMovie",
#     "name": "#AddSoccerRuinAMovie",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Mohsni",
#     "query": "Mohsni",
#     "name": "Mohsni",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Moshni",
#     "query": "Moshni",
#     "name": "Moshni",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SweetRiotShowcaseLive",
#     "query": "%23SweetRiotShowcaseLive",
#     "name": "#SweetRiotShowcaseLive",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2015-05-31T17:45:53Z",
#   "locations": [
#    {
#     "woeid": 23424975,
#     "name": "United Kingdom"
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
nigeria_trends_set = set([trend['name'] for trend in nigeria_trends[0]['trends']])
print nigeria_trends_set
print

uk_trends_set = set([trend['name'] for trend in uk_trends[0]['trends']])
print uk_trends_set
print

usa_trends_set = set([trend['name'] for trend in united_states_trends[0]['trends']])
print usa_trends_set
print

uk_usa_trends = uk_trends_set.intersection(usa_trends_set)
print uk_usa_trends
print

uk_ngr_trends = uk_trends_set.intersection(nigeria_trends_set)
print uk_ngr_trends
print

usa_ngr_trends = nigeria_trends_set.intersection(usa_trends_set)
print usa_ngr_trends
print
# Out:
# set([u'Sanchez', u'#SundayGroove', u'Messi', u'Jack Wilshere', u'#FlamzNATION_1EOY', u'Arsenal', u'#JJCAFROBEATSLIVE', u'#MOTYconcertTonight', u'#SundayChilloutZone', u'Tottenham'])
#
# set([u'Motherwell', u'#ConnorFrantaTwitterMeetUp', u'#SweetRiotShowcaseLive', u'#AskFifthHarmony', u'Moshni', u'Rangers', u'#askthescript', u'#AddSoccerRuinAMovie', u'The 1975', u'Mohsni'])
#
# set([u'John Kerry', u'#FakeApocalypseFacts', u'#ConnorFrantaTwitterMeetUp', u'Brian Williams', u'#InsteadOfGoingToChurchIm', u'#ZaynMalikInManila', u'#SundayFunday', u'The 1975', u'Berdych', u'Clint Eastwood'])
#
# set([u'The 1975', u'#ConnorFrantaTwitterMeetUp'])
#
# set([])
#
# set([])

# %% [markdown]
# ## Example 5. Collecting search results

# %%
# Import unquote to prevent url encoding errors in next_results
from urllib import unquote

# XXX: Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.

q = '#Buhari' 

count = 200

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print "Length of statuses", len(statuses)
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError, e: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in unquote(next_results[1:]).split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']


# Show one sample search result by slicing the list...
print json.dumps(statuses[0], indent=1)
# Out:
# Length of statuses 100
# Length of statuses
#  200
# Length of statuses
#  300
# Length of statuses
#  400
# Length of statuses
#  500
# {
#  "contributors": null,
#  "truncated": false,
#  "text": "@RFI: Info RFI: #buhari au #Niger pour son premier d\u00e9placement \u00e0 l'\u00e9tranger http://t.co/ftYQmbfbua  #ne227 http://t.co/BCLCwCCutY",
#  "is_quote_status": false,
#  "in_reply_to_status_id": null,
#  "id": 605071441684516864,
#  "favorite_count": 0,
#  "source": "<a href=\"http://test.baobab.net\" rel=\"nofollow\">t.autoshare</a>",
#  "retweeted": false,
#  "coordinates": null,
#  "entities": {
#   "symbols": [],
#   "user_mentions": [
#    {
#     "id": 32861321,
#     "indices": [
#      0,
#      4
#     ],
#     "id_str": "32861321",
#     "screen_name": "RFI",
#     "name": "RFI"
#    }
#   ],
#   "hashtags": [
#    {
#     "indices": [
#      16,
#      23
#     ],
#     "text": "buhari"
#    },
#    {
#     "indices": [
#      27,
#      33
#     ],
#     "text": "Niger"
#    },
#    {
#     "indices": [
#      100,
#      106
#     ],
#     "text": "ne227"
#    }
#   ],
#   "urls": [
#    {
#     "url": "http://t.co/ftYQmbfbua",
#     "indices": [
#      76,
#      98
#     ],
#     "expanded_url": "http://b1885.info/l.php?i=n20420",
#     "display_url": "b1885.info/l.php?i=n20420"
#    }
#   ],
#   "media": [
#    {
#     "expanded_url": "http://twitter.com/b_1885/status/605071441684516864/photo/1",
#     "display_url": "pic.twitter.com/BCLCwCCutY",
#     "url": "http://t.co/BCLCwCCutY",
#     "media_url_https": "https://pbs.twimg.com/media/CGWlRTSWgAAWqzb.jpg",
#     "id_str": "605071441604804608",
#     "sizes": {
#      "small": {
#       "h": 97,
#       "resize": "fit",
#       "w": 130
#      },
#      "large": {
#       "h": 97,
#       "resize": "fit",
#       "w": 130
#      },
#      "medium": {
#       "h": 97,
#       "resize": "fit",
#       "w": 130
#      },
#      "thumb": {
#       "h": 97,
#       "resize": "crop",
#       "w": 130
#      }
#     },
#     "indices": [
#      107,
#      129
#     ],
#     "type": "photo",
#     "id": 605071441604804608,
#     "media_url": "http://pbs.twimg.com/media/CGWlRTSWgAAWqzb.jpg"
#    }
#   ]
#  },
#  "in_reply_to_screen_name": "RFI",
#  "in_reply_to_user_id": 32861321,
#  "retweet_count": 0,
#  "id_str": "605071441684516864",
#  "favorited": false,
#  "user": {
#   "follow_request_sent": false,
#   "profile_use_background_image": false,
#   "default_profile_image": false,
#   "id": 2700937848,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme13/bg.gif",
#   "verified": false,
#   "profile_text_color": "333333",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/570513905948962816/uaGA_O-1_normal.png",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "http://t.co/qey56FMG5b",
#       "indices": [
#        0,
#        22
#       ],
#       "expanded_url": "http://b1885.info",
#       "display_url": "b1885.info"
#      }
#     ]
#    },
#    "description": {
#     "urls": [
#      {
#       "url": "https://t.co/z6SD06mtEe",
#       "indices": [
#        105,
#        128
#       ],
#       "expanded_url": "https://www.facebook.com/b1885",
#       "display_url": "facebook.com/b1885"
#      }
#     ]
#    }
#   },
#   "followers_count": 1153,
#   "profile_sidebar_border_color": "000000",
#   "id_str": "2700937848",
#   "profile_background_color": "F8F8F8",
#   "listed_count": 11,
#   "is_translation_enabled": false,
#   "utc_offset": 7200,
#   "statuses_count": 18325,
#   "description": "Afrique: Actualit\u00e9, Histoire, Litt\u00e9rature et Audiovisuel. Par des jeunes africains pour les africains... https://t.co/z6SD06mtEe",
#   "friends_count": 283,
#   "location": "Afrique",
#   "profile_link_color": "94D487",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/570513905948962816/uaGA_O-1_normal.png",
#   "following": false,
#   "geo_enabled": false,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/2700937848/1426204809",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme13/bg.gif",
#   "screen_name": "b_1885",
#   "lang": "fr",
#   "profile_background_tile": true,
#   "favourites_count": 14,
#   "name": "b1885",
#   "notifications": false,
#   "url": "http://t.co/qey56FMG5b",
#   "created_at": "Sat Aug 02 14:34:50 +0000 2014",
#   "contributors_enabled": false,
#   "time_zone": "Brussels",
#   "protected": false,
#   "default_profile": false,
#   "is_translator": false
#  },
#  "geo": null,
#  "in_reply_to_user_id_str": "32861321",
#  "possibly_sensitive": false,
#  "lang": "fr",
#  "created_at": "Sun May 31 18:00:48 +0000 2015",
#  "in_reply_to_status_id_str": null,
#  "place": null,
#  "metadata": {
#   "iso_language_code": "fr",
#   "result_type": "recent"
#  }
# }

# %%
# print search_results.get('search_metadata')['next_results']

# print search_results['search_metadata']['next_results']

# print unquote(next_results[1:]).split("&")
# print 

# print dict([ kv.split('=') for kv in unquote(next_results[1:]).split("&") ])
# print
    
# print json.dumps(search_results.keys(), indent=1)
# print 

# print json.dumps(search_results.get('search_metadata'), indent=1)
# print 

# chk = json.dumps(search_results.get('statuses'), indent=1)
# print(chk)

statuses[0].keys()
# Out:
# [u'contributors',
#  u'truncated',
#  u'text',
#  u'is_quote_status',
#  u'in_reply_to_status_id',
#  u'id',
#  u'favorite_count',
#  u'source',
#  u'retweeted',
#  u'coordinates',
#  u'entities',
#  u'in_reply_to_screen_name',
#  u'in_reply_to_user_id',
#  u'retweet_count',
#  u'id_str',
#  u'favorited',
#  u'user',
#  u'geo',
#  u'in_reply_to_user_id_str',
#  u'possibly_sensitive',
#  u'lang',
#  u'created_at',
#  u'in_reply_to_status_id_str',
#  u'place',
#  u'metadata']

# %% [markdown]
# Note: Should you desire to do so, you can load the same set of search results that are illustrated in the text of _Mining the Social Web_ by executing the code below that reads a snapshot of the data and stores it into the same statuses variable as was defined above. Alternatively, you can choose to skip execution of this cell in order to follow along with your own data.

# %%
import json
statuses = json.loads(open('resources/ch01-twitter/data/MentionSomeoneImportantForYou.json').read())

# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = [ status 
      for status in statuses
          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print t['retweet_count']
print t['retweeted_status']

# Can you find the most retweeted tweet in your search results? Try do do it!

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# # Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# # Explore the first 5 items for each...
    

print json.dumps(status_texts[0:5], indent=1)
print json.dumps(screen_names[0:5], indent=1) 
print json.dumps(hashtags[0:5], indent=1)
print json.dumps(words[0:5], indent=1)
# Out:
# [
#  "@RFI: Info RFI: #buhari au #Niger pour son premier d\u00e9placement \u00e0 l'\u00e9tranger http://t.co/ftYQmbfbua  #ne227 http://t.co/BCLCwCCutY",
#  "President #Buhari's first visit abroad is expected to be to #Niger Republic with military cooperation on the agenda  http://t.co/1HioRwphvF",
#  "#Buhari's Cabinet: Series of meeting, Calculation and Permutation still on-going now as Nigerians awaits the... http://t.co/QClsGv7ZkS",
#  "I think this photo says it all... #Nigeria #Buhari http://t.co/rMiykfRY84",
#  "RT @chairmanNHRC: #SERAP urges #Buhari, #Osinbajo to declare assets publicly -  http://t.co/jGwg6lrpnA"
# ]
# [
#  "RFI",
#  "chairmanNHRC",
#  "victor_mbidi",
#  "chairmanNHRC",
#  "victor_mbidi"
# ]
# [
#  "buhari",
#  "Niger",
#  "ne227",
#  "Buhari",
#  "Niger"
# ]
# [
#  "@RFI:",
#  "Info",
#  "RFI:",
#  "#buhari",
#  "au"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print c.most_common()[:10] # top 10
    print
# Out:
# [(u'#Buhari', 380), (u'RT', 269), (u'to', 232), (u'of', 137), (u'#Nigeria', 127), (u'the', 123), (u'in', 120), (u'not', 85), (u'I', 76), (u'&amp;', 75)]
#
# [(u'dupekilla', 66), (u'naijcom', 28), (u'jeune_afrique', 18), (u'victor_mbidi', 16), (u'mamadou', 10), (u'noh_outhman', 10), (u'chairmanNHRC', 10), (u'fortius0', 9), (u'AFP', 8), (u'RichardGrenell', 7)]
#
# [(u'Buhari', 549), (u'Nigeria', 168), (u'buhari', 39), (u'socialmedia', 38), (u'Osinbajo', 28), (u'BokoHaram', 24), (u'ChangeIsHere', 22), (u'Inauguration', 19), (u'Gamboru', 18), (u'nigeria', 17)]

# %% [markdown]
# ## Example 8. Using prettytable to display tuples in a nice tabular format

# %%
from prettytable import PrettyTable

for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print pt
# Out:
# +----------+-------+
# | Word     | Count |
# +----------+-------+
# | #Buhari  |   380 |
# | RT       |   269 |
# | to       |   232 |
# | of       |   137 |
# | #Nigeria |   127 |
# | the      |   123 |
# | in       |   120 |
# | not      |    85 |
# | I        |    76 |
# | &amp;    |    75 |
# +----------+-------+
# +----------------+-------+
# | Screen Name    | Count |
# +----------------+-------+
# | dupekilla      |    66 |
# | naijcom        |    28 |
# | jeune_afrique  |    18 |
# | victor_mbidi   |    16 |
# | mamadou        |    10 |
# | noh_outhman    |    10 |
# | chairmanNHRC   |    10 |
# | fortius0       |     9 |
# | AFP            |     8 |
# | RichardGrenell |     7 |
# +----------------+-------+
# +--------------+-------+
# | Hashtag      | Count |
# +--------------+-------+
# | Buhari       |   549 |
# | Nigeria      |   168 |
# | buhari       |    39 |
# | socialmedia  |    38 |
# | Osinbajo     |    28 |
# | BokoHaram    |    24 |
# | ChangeIsHere |    22 |
# | Inauguration |    19 |
# | Gamboru      |    18 |
# | nigeria      |    17 |
# +--------------+-------+

# %% [markdown]
# ## Example 9. Calculating lexical diversity for tweets

# %%
# A function for computing lexical diversity
def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens) 

# A function for computing the average number of words per tweet
def average_words(statuses):
    total_words = sum([ len(s.split()) for s in statuses ]) 
    return 1.0*total_words/len(statuses)

print lexical_diversity(words)
print lexical_diversity(screen_names)
print lexical_diversity(hashtags)
print average_words(status_texts)
# Out:
# 0.250278086763
# 0.329571106095
# 0.211206896552
# 16.4816666667

# %% [markdown]
# ## Example 10. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text']) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if status.has_key('retweeted_status')
           ]

# Slice off the first 5 from the sorted results and display each item in the tuple

pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
[ pt.add_row(row) for row in sorted(retweets, reverse=True)[:5] ]
pt.max_width['Text'] = 50
pt.align= 'l'
print pt

# %% [markdown]
# ## Example 11. Looking up users who have retweeted a status

# %%
# Get the original tweet id for a tweet from its retweeted_status node 
# and insert it here in place of the sample value that is provided
# from the text of the book

_retweets = twitter_api.statuses.retweets(id=317127304981667841)
print [r['user']['screen_name'] for r in _retweets]

# %% [markdown]
# ## Example 12. Plotting frequencies of words

# %%
word_counts = sorted(Counter(words).values(), reverse=True)

plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")

# %% [markdown]
# ## Example 13. Generating histograms of words, screen names, and hashtags

# %%
for label, data in (('Words', words), 
                    ('Screen Names', screen_names), 
                    ('Hashtags', hashtags)):

    # Build a frequency map for each set of data
    # and plot the values
    c = Counter(data)
    plt.hist(c.values())
    
    # Add a title and y-label ...
    plt.title(label)
    plt.ylabel("Number of items in bin")
    plt.xlabel("Bins (number of times an item appeared)")
    
    # ... and display as a new figure
    plt.figure()

# %% [markdown]
# ## Example 14. Generating a histogram of retweet counts

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

plt.hist(counts)
plt.title("Retweets")
plt.xlabel('Bins (number of times retweeted)')
plt.ylabel('Number of tweets in bin')

print counts

# %% [markdown]
# Note: This histogram gives you an idea of how many times tweets are retweeted with the x-axis defining partitions for tweets that have been retweeted some number of times and the y-axis telling you how many tweets fell into each bin. For example, a y-axis value of 5 for the "15-20 bin" on the x-axis means that there were 5 tweets that were retweeted between 15 and 20 times.
#
# Here's another variation that transforms the data using the (automatically imported from numpy) log function in order to improve the resolution of the plot.

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

# Taking the log of the *data values* themselves can 
# often provide quick and valuable insight into the
# underlying distribution as well. Try it back on
# Example 13 and see if it helps.

plt.hist(log(counts))
plt.title("Retweets")
plt.xlabel('Log[Bins (number of times retweeted)]')
plt.ylabel('Log[Number of tweets in bin]')

print log(counts)
